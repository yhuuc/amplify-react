# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
import librosa

# %%
filename  = librosa.example('nutcracker')

# %%
y, sc = librosa.load(filename)

# %%
plt.plot(y)

# %%
tempo, beat_frames = librosa.beat.beat_track(y=y,sr=sc)

# %%
beat_times = librosa.frames_to_time(beat_frames, sr=sc)

# %%
tempo
# Out:
# 107.666015625
