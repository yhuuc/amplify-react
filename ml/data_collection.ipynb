# %% [markdown]
# # Data Collection

# %% [markdown]
# ## Collecting Popular Songs from Billboard Data Scraping

# %%
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
# get Hot 100 for each year
def get_hot100(year=2023):
    # get data from billboard Year-End Hot-100 Songs Chart
    url = 'https://www.billboard.com/charts/year-end/' + str(year) + '/hot-100-songs/'
    page = urlopen(url)
    html = page.read().decode("utf-8")
    soup = BeautifulSoup(html, "html.parser")
    # get text only, remove \t and \n
    html_text = soup.get_text().replace('\t','').split('\n')
    # remove empty strings and whitespaces
    html_text[:] = [i for i in html_text if i!='' and not i.isspace()]
    # convert to list
    ls = []
    for rank in range(1,101):
        i = html_text.index(str(rank))
        ls.append(html_text[i:i+3])
    # convert to pd dataframe
    df = pd.DataFrame(ls, columns = ['billboard_ranking', 'song', 'artist'])
    df['year'] = year
    df['popular_or_not']=1
    df = df.convert_dtypes()
    return df

# %%
hot100_2023 = get_hot100(2023)

# %%
# # save data to local file
# hot100_2023.to_csv('billboardHot100_2023.csv',index=False)

# %% [markdown]
# ## Collecting Necessary Information of Popular Songs from Spotify
# This section, using above 100 songs from billboard Hot 100, retrieves their track ID, album name, album ID, popularity score (out of 100), and url link to a 30s song snippet from Spotify API. These info are necessary for collecting unpopular songs, song snippet links will be used in audio feature extraction.

# %%
import pandas as pd
from urllib.parse import quote

# %%
# Connect to Spotify API
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

# %%
# Search a specific Spotify track ID based on song name and artist name
def get_track_id(tracks, artists):
    track_id=[]

    for t, a in zip(tracks, artists):
        a = a.replace('Featuring ','')
        query = quote('track:' + t + ' artist:' + a)
        search_result = spotify.search(q=query, type="track", market="AU", limit=1, offset=0)['tracks']['items']
        if len(search_result)>0:
            track_id.append(search_result[0]['id'])
        else:
            track_id.append(None)

    return track_id

# %%
hot100_2023['track_id'] = get_track_id(hot100_2023['song'], hot100_2023['artist'])

# %%
hot100_2023['track_id'].count()
# Out:
# 100

# %%
# hot100_2023.to_csv('billboard_hot100_2023.csv', index = False)

# %%
hot100_2023
# Out:
#    billboard_ranking                          song  \
# 0                  1                    Last Night
# 1                  2                       Flowers
# 2                  3                     Kill Bill
# 3                  4                     Anti-Hero
# 4                  5                      Creepin'
# ..               ...                           ...
# 95                96  Bzrp Music Sessions, Vol. 53
# 96                97                      Meltdown
# 97                98      Put It On Da Floor Again
# 98                99                   Bloody Mary
# 99               100          Watermelon Moonshine
#
#                                   artist  year  popular_or_not  \
# 0                          Morgan Wallen  2023               1
# 1                            Miley Cyrus  2023               1
# 2                                    SZA  2023               1
# 3                           Taylor Swift  2023               1
# 4   Metro Boomin, The Weeknd & 21 Savage  2023               1
# ..                                   ...   ...             ...
# 95                    Bizarrap & Shakira  2023               1
# 96          Travis Scott Featuring Drake  2023               1
# 97               Latto Featuring Cardi B  2023               1
# 98                             Lady Gaga  2023               1
# 99                         Lainey Wilson  2023               1
#
#                   track_id
# 0   7K3BhSpAxZBznislvUMVtn
# 1   1ZJwhLQLt2quexYKP2Q3gk
# 2   2oqB9en8cOf6Sl9NMEeu7H
# 3   779ooI3rBd0CLqCiiJmtVo
# 4   2dHHgzDwk4BJdRwy9uXhTO
# ..                     ...
# 95  4nrPB8O7Y7wsOCJdgXkthe
# 96  0O9WkgPDfZ7A9DMDocF6ur
# 97  6c6WmIHcHlhccEwSFBhzNa
# 98  53jnnqFSRGMDB9ADrNriCA
# 99  3sYBFUXTv0STUoUINx9Qe8
#
# [100 rows x 6 columns]

# %%
def get_data(track_id):
    arr = [[] for _ in range(4)]
    
    for id in track_id:
        track_info = spotify.track(track_id=id, market='AU')
        arr[0].append(track_info['album']['name'])
        arr[1].append(track_info['album']['id'])
        arr[2].append(track_info['popularity'])
        arr[3].append(track_info['preview_url'])
    
    return arr

# %%
arr = get_data(hot100_2023['track_id'])

# %%
hot100_2023['album'], hot100_2023['album_id'], hot100_2023['spotify_popularity'], hot100_2023['audio_link'] = arr[0], arr[1], arr[2], arr[3]

# %%
hot100_2023
# Out:
#     billboard_ranking                          song  \
# 0                   1                    Last Night
# 1                   2                       Flowers
# 2                   3                     Kill Bill
# 3                   4                     Anti-Hero
# 4                   5                      Creepin'
# ..                ...                           ...
# 95                 96  Bzrp Music Sessions, Vol. 53
# 96                 97                      Meltdown
# 97                 98      Put It On Da Floor Again
# 98                 99                   Bloody Mary
# 99                100          Watermelon Moonshine
#
#                                   artist  year  popular_or_not  \
# 0                          Morgan Wallen  2023               1
# 1                            Miley Cyrus  2023               1
# 2                                    SZA  2023               1
# 3                           Taylor Swift  2023               1
# 4   Metro Boomin, The Weeknd & 21 Savage  2023               1
# ..                                   ...   ...             ...
# 95                    Bizarrap & Shakira  2023               1
# 96          Travis Scott Featuring Drake  2023               1
# 97               Latto Featuring Cardi B  2023               1
# 98                             Lady Gaga  2023               1
# 99                         Lainey Wilson  2023               1
#
#                   track_id  spotify_popularity  \
# 0   7K3BhSpAxZBznislvUMVtn                  85
# 1   7DSAEUvxU8FajXtRloy8M0                  92
# 2   3OHfY25tqY28d16oZczHc8                  83
# 3   0V3wPSX9ygBnCm8psDIegu                  89
# 4   2dHHgzDwk4BJdRwy9uXhTO                  87
# ..                     ...                 ...
# 95  4nrPB8O7Y7wsOCJdgXkthe                  64
# 96  0O9WkgPDfZ7A9DMDocF6ur                  83
# 97  6c6WmIHcHlhccEwSFBhzNa                  69
# 98  53jnnqFSRGMDB9ADrNriCA                  77
# 99  3sYBFUXTv0STUoUINx9Qe8                  77
#
#                                                 album                album_id  \
# 0                                 One Thing At A Time  6i7mF7whyRJuLJ4ogbH2wh
# 1                             Endless Summer Vacation  5DvJgsMLbaR1HmAI6VhfcQ
# 2                                                 SOS  07w0rG5TETcyihsEIZR3qG
# 3                                           Midnights  151w1FgRZfnKZA9FEcg9Z3
# 4                                   HEROES & VILLAINS  7txGsnDSqVMoRl6RQ9XyZP
# ..                                                ...                     ...
# 95                           Las Mujeres Ya No Lloran  3fonA82Hl7huJiQCwKkzGA
# 96                                             UTOPIA  18NOKLkZETa4sWwLMIm0UZ
# 97           Put It On Da Floor Again (feat. Cardi B)  4A43tzEN3jILvseI1HeXGG
# 98  Born This Way (International Special Edition V...  6LY3AerY6KNGOPsNPL63Kk
# 99                                Bell Bottom Country  06q6BDUpP6OS8Xnx3YC2M0
#
#                                            audio_link
# 0                                                 NaN
# 1   https://p.scdn.co/mp3-preview/5184d19d1b7fcc3e...
# 2   https://p.scdn.co/mp3-preview/49dfe4ea78c5d3c5...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95  https://p.scdn.co/mp3-preview/3ba573cb752298ab...
# 96  https://p.scdn.co/mp3-preview/7c7e0e4419d101bc...
# 97  https://p.scdn.co/mp3-preview/3cd934af8742a4c0...
# 98                                                NaN
# 99  https://p.scdn.co/mp3-preview/616455e085625d56...
#
# [100 rows x 10 columns]

# %%
# hot100_2023.to_csv('billboard_hot100_2023.csv', index = False)

# %% [markdown]
# ## Collecting Unpopular Songs

# %% [markdown]
# Spotify songs in the same album all have songs snippets (preview_url) or all don't
# Since we are getting songs from the same album, and need audio link to get audio features to train ML model, only tracks with a link are useful

# %%
import pandas as pd
import time

# %%
# Connect to Spotify API
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

# %%
hot100_2023 = pd.read_csv('billboard_hot100_2023.csv')

# %%
# drop all songs without links
popular_songs = hot100_2023.dropna(subset=['audio_link']).reset_index(drop=True)

# %%
len(popular_songs)
# Out:
# 55

# %%
popular_songs.to_csv('popular_songs.csv', index=False)

# %%
unpopular_songs = pd.DataFrame({
    'album': popular_songs['album'],
    'album_id': popular_songs['album_id'],
    'artist': popular_songs['artist'],
    'year': popular_songs['year'],
    'billboard_ranking': 0,
    'popular_or_not': 0
})

# %%
unpopular_songs.head(5)
# Out:
#                      album                album_id                     artist  \
# 0  Endless Summer Vacation  5DvJgsMLbaR1HmAI6VhfcQ                Miley Cyrus
# 1                      SOS  07w0rG5TETcyihsEIZR3qG                        SZA
# 2              Gettin' Old  5Uly85dJHHDfHQCsyUQ8gw                 Luke Combs
# 3                      SOS  07w0rG5TETcyihsEIZR3qG                        SZA
# 4                     Bebe  0FWLTTcCKsd3b1PiW9GTEN  David Guetta & Bebe Rexha
#
#    year  billboard_ranking  popular_or_not
# 0  2023                  0               0
# 1  2023                  0               0
# 2  2023                  0               0
# 3  2023                  0               0
# 4  2023                  0               0

# %%
def get_unpopular_track(album_ids):
    arr = [[] for _ in range(4)]

    for id in album_ids:
        search_result = spotify.album_tracks(album_id=id, market='AU')
        # get all tracks in an album
        album_tracks = {track['id']: None for track in search_result['items']}
        # record their popularity scores
        for id in album_tracks:
            track = spotify.track(track_id=id, market='AU')
            album_tracks[id] = track['popularity']
        # find the one with lowest score
        min_key = min(album_tracks, key=lambda k: album_tracks[k])
        track = spotify.track(track_id=min_key, market='AU')
        arr[0].append(track['name'])
        arr[1].append(track['id'])
        arr[2].append(track['popularity'])
        arr[3].append(track['preview_url'])
        # add a 30s timer to avoid Spotify API rate limit
        time.sleep(30)
    
    return arr

# %%
# because need to work around spotify's api rate limit, this operation will take 30min
arr = get_unpopular_track(unpopular_songs['album_id'])

# %%
unpopular_songs['song'], unpopular_songs['track_id'], unpopular_songs['spotify_popularity'], unpopular_songs['audio_link'] = arr[0], arr[1], arr[2], arr[3]

# %%
unpopular_songs.head(5)
# Out:
#                      album                album_id                     artist  \
# 0  Endless Summer Vacation  5DvJgsMLbaR1HmAI6VhfcQ                Miley Cyrus
# 1                      SOS  07w0rG5TETcyihsEIZR3qG                        SZA
# 2              Gettin' Old  5Uly85dJHHDfHQCsyUQ8gw                 Luke Combs
# 3                      SOS  07w0rG5TETcyihsEIZR3qG                        SZA
# 4                     Bebe  0FWLTTcCKsd3b1PiW9GTEN  David Guetta & Bebe Rexha
#
#    year  billboard_ranking  popular_or_not             song  \
# 0  2023                  0               0        Handstand
# 1  2023                  0               0         Too Late
# 2  2023                  0               0  A Song Was Born
# 3  2023                  0               0         Too Late
# 4  2023                  0               0       Born Again
#
#                  track_id  spotify_popularity  \
# 0  6eiNVtWCRsU7N6JDPXFI2W                  56
# 1  4rAg5bbrdZX00mXXhLvYXj                  66
# 2  4AhZSJyGTfYqUnFjn5eGQa                  55
# 3  4rAg5bbrdZX00mXXhLvYXj                  66
# 4  29y1cN7e9sTX0gBx4y7OCv                  32
#
#                                           audio_link
# 0  https://p.scdn.co/mp3-preview/c55b106ce42d91f0...
# 1  https://p.scdn.co/mp3-preview/cfd6bdd6babe9cea...
# 2  https://p.scdn.co/mp3-preview/3cb99b6f94fb1007...
# 3  https://p.scdn.co/mp3-preview/cfd6bdd6babe9cea...
# 4  https://p.scdn.co/mp3-preview/2cfae3cf9aa275f7...

# %%
unpopular_songs.to_csv('unpopular_songs.csv', index=False)

# %% [markdown]
# ## Composing all_songs Data

# %%
import pandas as pd

# %%
popular_songs = pd.read_csv('popular_songs.csv')
unpopular_songs = pd.read_csv('unpopular_songs.csv')

# %%
all_songs = pd.concat([popular_songs,unpopular_songs], axis=0)

# %%
all_songs
# Out:
#     billboard_ranking                                         song  \
# 0                   2                                      Flowers
# 1                   3                                    Kill Bill
# 2                   8                                     Fast Car
# 3                   9                                       Snooze
# 4                  10                              I'm Good (Blue)
# ..                ...                                          ...
# 46                  0                                   Hot Grease
# 47                  0  Bzrp Music Sessions, Vol. 53 - Tiësto Remix
# 48                  0  PARASAIL (feat. Yung Lean & Dave Chappelle)
# 49                  0      Put It On Da Floor Again - Instrumental
# 50                  0                     This One's Gonna Cost Me
#
#                             artist  year  popular_or_not  \
# 0                      Miley Cyrus  2023               1
# 1                              SZA  2023               1
# 2                       Luke Combs  2023               1
# 3                              SZA  2023               1
# 4        David Guetta & Bebe Rexha  2023               1
# ..                             ...   ...             ...
# 46  Young Nudy Featuring 21 Savage  2023               0
# 47              Bizarrap & Shakira  2023               0
# 48    Travis Scott Featuring Drake  2023               0
# 49         Latto Featuring Cardi B  2023               0
# 50                   Lainey Wilson  2023               0
#
#                   track_id  spotify_popularity  \
# 0   7DSAEUvxU8FajXtRloy8M0                  92
# 1   3OHfY25tqY28d16oZczHc8                  83
# 2   1Lo0QY9cvc8sUB2vnIOxDT                  87
# 3   4iZ4pt7kvcaH6Yo8UoZ4s2                  91
# 4   4uUG5RXrOk84mYEfFvj3cK                  90
# ..                     ...                 ...
# 46  3guv5zn5hDfpPpKfcmCTxS                  39
# 47  22Q0eVNpSUIWG0prN6cVmI                  63
# 48  2Q0aElTZQtEUsoiaQfizu6                  68
# 49  3H2tSGsIkHnhT2tuHiHtAF                  25
# 50  7C3v6v5UV1qdFYcNzvJTyg                  45
#
#                                        album                album_id  \
# 0                    Endless Summer Vacation  5DvJgsMLbaR1HmAI6VhfcQ
# 1                                        SOS  07w0rG5TETcyihsEIZR3qG
# 2                                Gettin' Old  5Uly85dJHHDfHQCsyUQ8gw
# 3                                        SOS  07w0rG5TETcyihsEIZR3qG
# 4                                       Bebe  0FWLTTcCKsd3b1PiW9GTEN
# ..                                       ...                     ...
# 46                                     Gumbo  1UbeEAPS49eulB659XSU9g
# 47                  Las Mujeres Ya No Lloran  3fonA82Hl7huJiQCwKkzGA
# 48                                    UTOPIA  18NOKLkZETa4sWwLMIm0UZ
# 49  Put It On Da Floor Again (feat. Cardi B)  4A43tzEN3jILvseI1HeXGG
# 50                       Bell Bottom Country  06q6BDUpP6OS8Xnx3YC2M0
#
#                                            audio_link
# 0   https://p.scdn.co/mp3-preview/5184d19d1b7fcc3e...
# 1   https://p.scdn.co/mp3-preview/49dfe4ea78c5d3c5...
# 2   https://p.scdn.co/mp3-preview/1dc0426c95058783...
# 3   https://p.scdn.co/mp3-preview/8c53920b5fd2c317...
# 4   https://p.scdn.co/mp3-preview/c1de960c1a98f7ab...
# ..                                                ...
# 46  https://p.scdn.co/mp3-preview/b245449843dff7ea...
# 47  https://p.scdn.co/mp3-preview/3ba573cb752298ab...
# 48  https://p.scdn.co/mp3-preview/82f3c0d5844693c4...
# 49  https://p.scdn.co/mp3-preview/7844fd6714a5ee13...
# 50  https://p.scdn.co/mp3-preview/7533863e1c9fb727...
#
# [106 rows x 10 columns]

# %%
all_songs = all_songs.drop(columns=['artist','year','track_id','album','album_id'])

# %%
all_songs
# Out:
#     billboard_ranking                                         song  \
# 0                   2                                      Flowers
# 1                   3                                    Kill Bill
# 2                   8                                     Fast Car
# 3                   9                                       Snooze
# 4                  10                              I'm Good (Blue)
# ..                ...                                          ...
# 46                  0                                   Hot Grease
# 47                  0  Bzrp Music Sessions, Vol. 53 - Tiësto Remix
# 48                  0  PARASAIL (feat. Yung Lean & Dave Chappelle)
# 49                  0      Put It On Da Floor Again - Instrumental
# 50                  0                     This One's Gonna Cost Me
#
#     popular_or_not  spotify_popularity  \
# 0                1                  92
# 1                1                  83
# 2                1                  87
# 3                1                  91
# 4                1                  90
# ..             ...                 ...
# 46               0                  39
# 47               0                  63
# 48               0                  68
# 49               0                  25
# 50               0                  45
#
#                                            audio_link
# 0   https://p.scdn.co/mp3-preview/5184d19d1b7fcc3e...
# 1   https://p.scdn.co/mp3-preview/49dfe4ea78c5d3c5...
# 2   https://p.scdn.co/mp3-preview/1dc0426c95058783...
# 3   https://p.scdn.co/mp3-preview/8c53920b5fd2c317...
# 4   https://p.scdn.co/mp3-preview/c1de960c1a98f7ab...
# ..                                                ...
# 46  https://p.scdn.co/mp3-preview/b245449843dff7ea...
# 47  https://p.scdn.co/mp3-preview/3ba573cb752298ab...
# 48  https://p.scdn.co/mp3-preview/82f3c0d5844693c4...
# 49  https://p.scdn.co/mp3-preview/7844fd6714a5ee13...
# 50  https://p.scdn.co/mp3-preview/7533863e1c9fb727...
#
# [106 rows x 5 columns]

# %%
all_songs.to_csv("all_songs.csv", index=False)
